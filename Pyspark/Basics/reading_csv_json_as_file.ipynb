# %% [markdown]
# ### Data Reading

# %%
dbutils.fs.ls('/FileStore/tables/')
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-5001200704048839>, line 1
# ----> 1 dbutils.fs.ls('/FileStore/tables/')
#
# File /databricks/python_shell/lib/dbruntime/remotefshandler/RemoteFsHandler.py:54, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#      51 class ExecutionError(Exception):
#      52     pass
# ---> 54 raise ExecutionError(str(e)) from None
#
# ExecutionError: Public DBFS root is disabled. Access is denied on path: /FileStore/tables
#
# JVM stacktrace:
# java.lang.UnsupportedOperationException
# 	at com.databricks.backend.daemon.data.client.DisabledDatabricksFileSystem.rejectOperation(DisabledDatabricksFileSystem.scala:31)
# 	at com.databricks.backend.daemon.data.client.DisabledDatabricksFileSystem.listStatus(DisabledDatabricksFileSystem.scala:96)
# ...

# %%
# Reading file

df_file = spark.read.format('csv').option('inferschema',True).option('header',True).load('/Volumes/workspace/default/pytutorial/BigMart Sales.csv')

# %%
display(df_file.head(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_table = spark.read.table('workspace.default.big_mart_sales')
display(df.head(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### Reading JSON

# %%
# workspace.default.drivers
df_json = spark.read.format('json').option('inferSchema',True)\
    .option('header',True)\
        .option('multiline',False)\
            .load('workspace.default.drivers')
display(df_json.head(3))
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-5001200704048840>, line 6
#       1 # workspace.default.drivers
#       2 df_json = spark.read.format('json').option('inferSchema',True)\
#       3     .option('header',True)\
#       4         .option('multiline',False)\
#       5             .load('workspace.default.drivers')
# ----> 6 display(df_json.head(3))
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:687, in DataFrame.head(self, n)
#     685     rs = self.head(1)
#     686     return rs[0] if rs else None
# --> 687 return self.take(n)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:690, in DataFrame.take(self, num)
#     689 def take(self, num: int) -> List[Row]:
# --> 690     return self.limit(num).collect()
#
# ...

# %%
df_json = spark.read.table('workspace.default.drivers')
display(df_json.head(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>code</th><th>dob</th><th>driverId</th><th>driverRef</th><th>name</th><th>nationality</th><th>number</th><th>url</th></tr></thead><tbody><tr><td>HAM</td><td>1985-01-07T00:00:00.000Z</td><td>1</td><td>hamilton</td><td>List(Lewis, Hamilton)</td><td>British</td><td>44</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td></tr></tbody></table></div>

# %% [markdown]
# ### Schema Definition

# %%
df.printSchema()
# Out:
# root
#  |-- Item_Identifier: string (nullable = true)
#  |-- Item_Weight: double (nullable = true)
#  |-- Item_Fat_Content: string (nullable = true)
#  |-- Item_Visibility: double (nullable = true)
#  |-- Item_Type: string (nullable = true)
#  |-- Item_MRP: double (nullable = true)
#  |-- Outlet_Identifier: string (nullable = true)
#  |-- Outlet_Establishment_Year: long (nullable = true)
#  |-- Outlet_Size: string (nullable = true)
#  |-- Outlet_Location_Type: string (nullable = true)
#  |-- Outlet_Type: string (nullable = true)
#  |-- Item_Outlet_Sales: double (nullable = true)

# %% [markdown]
# ### DDL Schema

# %%
my_ddl_schema = """
            Item_Identifier string,
            Item_Weight string,
            Item_Fat_Content string,
            Item_Visibility double,
            Item_Type string,
            Item_MRP double,
            Outlet_Identifier string,
            Outlet_Establishment_Year long,
            Outlet_Size string,
            Outlet_Location_Type string,
            Outlet_Type string,
            Item_Outlet_Sales double
            """
df_file = spark.read.format('csv')\
    .schema(my_ddl_schema)\
        .option('header',True)\
        .load('/Volumes/workspace/default/pytutorial/BigMart Sales.csv')

# %%
df_file.printSchema()
# Out:
# root
#  |-- Item_Identifier: string (nullable = true)
#  |-- Item_Weight: string (nullable = true)
#  |-- Item_Fat_Content: string (nullable = true)
#  |-- Item_Visibility: double (nullable = true)
#  |-- Item_Type: string (nullable = true)
#  |-- Item_MRP: double (nullable = true)
#  |-- Outlet_Identifier: string (nullable = true)
#  |-- Outlet_Establishment_Year: long (nullable = true)
#  |-- Outlet_Size: string (nullable = true)
#  |-- Outlet_Location_Type: string (nullable = true)
#  |-- Outlet_Type: string (nullable = true)
#  |-- Item_Outlet_Sales: double (nullable = true)

# %% [markdown]
# ### StructType() Schema

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
# True allows null values
my_struct_schema = StructType([
    StructField('Item_Identifier',StringType(),True),
    StructField('Item_Weight',StringType(),True),
    StructField('Item_Fat_Content',StringType(),True),
    StructField('Item_Visibility',DoubleType(),True)
])

# %%
df_file = spark.read.format('csv')\
    .schema(my_struct_schema)\
        .option('header',True)\
        .load('/Volumes/workspace/default/pytutorial/BigMart Sales.csv')   
df_file.printSchema()
# Out:
# root
#  |-- Item_Identifier: string (nullable = true)
#  |-- Item_Weight: string (nullable = true)
#  |-- Item_Fat_Content: string (nullable = true)
#  |-- Item_Visibility: double (nullable = true)
